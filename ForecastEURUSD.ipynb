# %%
import pandas as pd
from nixtlats import TimeGPT

# %%
timegpt = TimeGPT(token = '')
timegpt.validate_token()
# Out:
# INFO:nixtlats.timegpt:Happy Forecasting! :), If you have questions or need support, please email ops@nixtla.io
# True

# %%
df = pd.read_csv('interpolated_data.csv')
df.head()
# Out:
#     timestamp    value
# 0  2008-01-29  1.47659
# 1  2008-01-30  1.48247
# 2  2008-01-31  1.48619
# 3  2008-02-01  1.47995
# 4  2008-02-02  1.47995

# %%
timegpt.plot(df, time_col='timestamp', target_col='value')
# Out:
# /home/dave/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
timegpt_fcst_df = timegpt.forecast(df=df, h=4, freq='D', time_col='timestamp', target_col='value')
timegpt_fcst_df.head()
# Out:
# INFO:nixtlats.timegpt:Validating inputs...
# INFO:nixtlats.timegpt:Preprocessing dataframes...
# INFO:nixtlats.timegpt:Calling Forecast Endpoint...
#     timestamp   TimeGPT
# 0  2024-02-08  1.077897
# 1  2024-02-09  1.077810
# 2  2024-02-10  1.077809
# 3  2024-02-11  1.077625

# %%
df.tail()
# Out:
#        timestamp    value
# 5849  2024-02-03  1.07849
# 5850  2024-02-04  1.07796
# 5851  2024-02-05  1.07410
# 5852  2024-02-06  1.07566
# 5853  2024-02-07  1.07701

# %%
timegpt.plot(df, timegpt_fcst_df, time_col='timestamp', target_col='value')

# %%
timegpt.plot(df, timegpt_fcst_df, time_col='timestamp', target_col='value')

# %%
timegpt.plot(timegpt_fcst_df, time_col='timestamp', target_col='TimeGPT')

# %%
from sklearn.linear_model import LinearRegression
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
timegpt_fcst_df['timestamp_numeric'] = (timegpt_fcst_df['timestamp'] - timegpt_fcst_df['timestamp'].min()).dt.days
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.10/site-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     219     try:
# --> 220         result = func(left, right)
#     221     except TypeError:
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_4706/3193096299.py in <module>
# ----> 1 timegpt_fcst_df['timestamp_numeric'] = (timegpt_fcst_df['timestamp'] - timegpt_fcst_df['timestamp'].min()).dt.days
#
# ~/.local/lib/python3.10/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      74         other = item_from_zerodim(other)
#      75
# ---> 76         return method(self, other)
#      77
# ...
